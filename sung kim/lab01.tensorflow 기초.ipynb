# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.0.0'

# %% [markdown]
# ### hello tensorflow!

# %%
hello = tf.constant("Hello, TensorFlow!")

print(hello)
# Out:
# tf.Tensor(b'Hello, TensorFlow!', shape=(), dtype=string)

# %% [markdown]
# ### Computational Graph

# %%
node1 = tf.constant(3.0, tf.float32)
node2 = tf.constant(4.0)

@tf.function
def forward():
    return node1+node2

out_a = forward()
print(out_a)
# Out:
# tf.Tensor(7.0, shape=(), dtype=float32)

# %% [markdown]
# ### tensorflow mechanics
# 1. tensorflow operation을 이용하여 그래프 빌드
# 2. 그래프 실행(session)
# 3. 그래프의 값 update
#
# ### tensor
# - rank : 차원
# - shape
# - types
